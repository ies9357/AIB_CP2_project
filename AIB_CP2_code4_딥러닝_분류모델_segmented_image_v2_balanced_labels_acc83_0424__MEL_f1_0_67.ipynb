# %% [markdown]
# #1.라이브러리 설치 및 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install barbar pytorch-ignite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting barbar
#   Downloading barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Collecting pytorch-ignite
#   Downloading pytorch_ignite-0.4.10-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 5.0 MB/s
# Requirement already satisfied: torch<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from pytorch-ignite) (1.12.1+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytorch-ignite) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<2,>=1.3->pytorch-ignite) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytorch-ignite) (3.0.9)
# Installing collected packages: pytorch-ignite, barbar
# Successfully installed barbar-0.2.1 pytorch-ignite-0.4.10

# %%
import torch
import os
import random
import torchvision
import pandas as pd
import torch.nn as nn
import numpy as np
from torchvision import transforms, datasets
from shutil import copyfile, move
from torch.utils.tensorboard import SummaryWriter
from barbar import Bar
from torchsummary import summary
from ignite.metrics import Accuracy
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_auc_score
random.seed(42)

# %% [markdown]
# #2.데이터 준비

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=50, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when monitored metric decrease.'''
        if self.verbose:
            self.trace_func(f'Monitored metric has improved ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), f'/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/skin_models_segmented/skinmodel50.pt') 
        self.val_loss_min = val_loss

# %%
def split_data(source, train, validation, test, train_split_size):    
    files = []
    for filename in os.listdir(source):
        file = source + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    train_length = int(len(files) * train_split_size)
    validation_length = int((len(files) - train_length) / 2)
    test_length = len(files) - train_length - validation_length

    shuffled_set = random.sample(files, len(files))
    train_set = shuffled_set[0:train_length]
    validation_set = shuffled_set[train_length:train_length + validation_length]
    test_set = shuffled_set[train_length + validation_length:]


    for filename in train_set:
        this_file = source + filename
        destination = train + filename
        copyfile(this_file, destination)

    for filename in validation_set:
        this_file = source + filename
        destination = validation + filename
        copyfile(this_file, destination)

    for filename in test_set:
        this_file = source + filename
        destination = test + filename
        copyfile(this_file, destination)

# %%
train_MEL = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/train/MEL/'
train_NV = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/train/NV/'
train_SC = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/train/Other_SC/'

valid_MEL = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/validation/MEL/'
valid_NV = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/validation/NV/'
valid_SC = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/validation/Other_SC/'

test_MEL = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/test/MEL/'
test_NV = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/test/NV/'
test_SC = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/new_data_v2_images/test/Other_SC/'


train_MEL_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/train/MEL/'
train_NV_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/train/NV/'
train_SC_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/train/Other_SC/'

valid_MEL_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/validation/MEL/'
valid_NV_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/validation/NV/'
valid_SC_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/validation/Other_SC/'

test_MEL_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/test/MEL/'
test_NV_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/test/NV/'
test_SC_seg = '/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/test/Other_SC/'

# %%
# import shutil

# from_dir = '/content/drive/MyDrive/Colab Notebooks/new_data_v3/images_segmented_v2/'


# for i in os.listdir(train_MEL):
#   shutil.copyfile(from_dir + 'MEL/' + i, train_MEL_seg + i)

# for i in os.listdir(valid_MEL):
#   shutil.copyfile(from_dir + 'MEL/' + i, valid_MEL_seg + i)

# for i in os.listdir(test_MEL):
#   shutil.copyfile(from_dir + 'MEL/' + i, test_MEL_seg + i)

# for i in os.listdir(train_NV):
#   shutil.copyfile(from_dir + 'NV/' + i, train_NV_seg + i)

# for i in os.listdir(valid_NV):
#   shutil.copyfile(from_dir + 'NV/' + i, valid_NV_seg + i)

# for i in os.listdir(test_NV):
#   shutil.copyfile(from_dir + 'NV/' + i, test_NV_seg + i)

# for i in os.listdir(train_SC):
#   shutil.copyfile(from_dir + 'Other_SC/' + i, train_SC_seg + i)

# for i in os.listdir(valid_SC):
#   shutil.copyfile(from_dir + 'Other_SC/' + i, valid_SC_seg + i)

# for i in os.listdir(test_SC):
#   shutil.copyfile(from_dir + 'Other_SC/' + i, test_SC_seg + i)

# %%
# 라벨 별 폴더에 저장된 image들을 train, validation, test폴더에 가고자 하는 데이터들로 분할 한 뒤 복사 붙혀넣기 하는 코드

# split_data(source_MEL, train_MEL, valid_MEL, test_MEL, 0.8)
# split_data(source_NV, train_NV, valid_NV, test_NV, 0.8)
# split_data(source_SC, train_SC, valid_SC, test_SC, 0.8)

# %%
print('-------------MEL-------------')
print('train 셋:', len(os.listdir(train_MEL_seg)))
print('validation 셋:', len(os.listdir(valid_MEL_seg)))
print('test 셋:', len(os.listdir(test_MEL_seg)))

print('-------------NV-------------')
print('train 셋:', len(os.listdir(train_NV_seg)))
print('validation 셋:', len(os.listdir(valid_NV_seg)))
print('test 셋:', len(os.listdir(test_NV_seg)))

print('-------------Other_SC-------------')
print('train 셋:', len(os.listdir(train_SC_seg)))
print('validation 셋:', len(os.listdir(valid_SC_seg)))
print('test 셋:', len(os.listdir(test_SC_seg)))
# Out:
# -------------MEL-------------
# train 셋: 1002
# validation 셋: 60
# test 셋: 51
# -------------NV-------------
# train 셋: 1002
# validation 셋: 324
# test 셋: 273
# -------------Other_SC-------------
# train 셋: 1002
# validation 셋: 117
# test 셋: 77

# %%
train_dir = r'/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/train/'
valid_dir = r'/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/validation/'
test_dir = r'/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/new_data_v2/images_segmented_train_valid_test/test/'

# %% [markdown]
# #3.데이터 증강

# %%
train_transforms = transforms.Compose([
    transforms.Resize((224, 280)),
    transforms.CenterCrop((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply(transforms=[transforms.RandomRotation(degrees=(-180, 180))], p=0.99),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

valid_transforms = transforms.Compose([
    transforms.Resize((224, 280)),
    torchvision.transforms.CenterCrop((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

test_transforms = transforms.Compose([
    transforms.Resize((224, 280)),
    torchvision.transforms.CenterCrop((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

train_dataset = datasets.ImageFolder(
    train_dir, transform=train_transforms)

valid_dataset = datasets.ImageFolder(
    valid_dir, transform=valid_transforms)

test_dataset = datasets.ImageFolder(
    test_dir, transform=test_transforms)

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=64, shuffle=True,
    pin_memory=False, drop_last=False)

valid_loader = torch.utils.data.DataLoader(
    valid_dataset, batch_size=64, shuffle=True,
    pin_memory=False, drop_last=False)

test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=64, shuffle=True,
    pin_memory=False, drop_last=False)

# %% [markdown]
# #4.모델학습

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model = torchvision.models.resnet50(pretrained=True).to(device)

model.fc = nn.Linear(2048, 3).to(device)

# model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/new_data_v3/skin_models_not_segmented/skinmodel50.pt')) 

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.7)
# optimizer = torch.optim.Adam(model.parameters(), weight_decay=0.0001)

epochs = 999

writer = SummaryWriter(log_dir='/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/skin_logs', filename_suffix="skin50")
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
# Shows info about model
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                    [-1, 3]           6,147
# ================================================================
# Total params: 23,514,179
# Trainable params: 23,514,179
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.55
# Params size (MB): 89.70
# Estimated Total Size (MB): 376.82
# ----------------------------------------------------------------

# %%
early_stopping = EarlyStopping(patience=50, verbose=True)

for epoch in range(epochs):
    train_loss = 0.00
    valid_loss = 0.00
    train_accuracy = Accuracy()
    valid_accuracy = Accuracy()
    print(f'Epoch {epoch+1}')

    # Training loop
    for idx, (inputs, labels) in enumerate(Bar(train_loader)):
        model.train()
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        loss = criterion(outputs, labels)
        loss.backward() 
        optimizer.step() 
        train_loss += loss.item()
        train_accuracy.update((nn.functional.softmax(outputs, dim=1), labels))
    print(f"Train Accuracy: {train_accuracy.compute()}")
    train_loss /= len(train_loader)
    train_loss_formated = "{:.4f}".format(train_loss)

    # Validation loop
    with torch.no_grad():
        for inputs, labels in valid_loader:
            model.eval()           
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item()
            valid_accuracy.update((nn.functional.softmax(outputs, dim=1), labels))
    print(f"Val Accuracy: {valid_accuracy.compute()}")
    valid_loss /= len(valid_loader)
    valid_loss_formated = "{:.4f}".format(valid_loss)
    print(f'Training Loss: {train_loss_formated}')
    print(f"Validation Loss: {valid_loss_formated}")

    # TensorBoard writer 
    writer.add_scalar('Loss/train', train_loss, epoch+1)
    writer.add_scalar('Loss/val', valid_loss, epoch+1)
    writer.add_scalar('Accuracy/train', train_accuracy.compute(), epoch+1)
    writer.add_scalar('Accuracy/val', valid_accuracy.compute(), epoch+1)

    # Early Stopping
    early_stopping(valid_loss, model)       
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# Epoch 1
# 3006/3006: [===============================>] - ETA 12.8s
# Train Accuracy: 0.5326014637391883
# Val Accuracy: 0.6706586826347305
# Training Loss: 0.9742
# Validation Loss: 0.8494
# Monitored metric has improved (inf --> 0.849445).  Saving model ...
# Epoch 2
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.6793080505655356
# Val Accuracy: 0.6906187624750499
# Training Loss: 0.7756
# Validation Loss: 0.7462
# Monitored metric has improved (0.849445 --> 0.746165).  Saving model ...
# Epoch 3
# 3006/3006: [===============================>] - ETA 0.7s
# Train Accuracy: 0.7065868263473054
# Val Accuracy: 0.6946107784431138
# Training Loss: 0.6927
# Validation Loss: 0.7006
# Monitored metric has improved (0.746165 --> 0.700579).  Saving model ...
# Epoch 4
# 3006/3006: [===============================>] - ETA 0.7s
# Train Accuracy: 0.7218895542248835
# Val Accuracy: 0.7504990019960079
# Training Loss: 0.6508
# Validation Loss: 0.6271
# Monitored metric has improved (0.700579 --> 0.627105).  Saving model ...
# Epoch 5
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7308715901530273
# Val Accuracy: 0.7265469061876247
# Training Loss: 0.6187
# Validation Loss: 0.6478
# EarlyStopping counter: 1 out of 50
# Epoch 6
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7441783100465735
# Val Accuracy: 0.7325349301397206
# Training Loss: 0.6031
# Validation Loss: 0.6115
# Monitored metric has improved (0.627105 --> 0.611516).  Saving model ...
# Epoch 7
# 3006/3006: [===============================>] - ETA 0.7s
# Train Accuracy: 0.7501663339986693
# Val Accuracy: 0.7704590818363274
# Training Loss: 0.5897
# Validation Loss: 0.5543
# Monitored metric has improved (0.611516 --> 0.554346).  Saving model ...
# Epoch 8
# 3006/3006: [===============================>] - ETA 0.7s
# Train Accuracy: 0.7551563539587491
# Val Accuracy: 0.7524950099800399
# Training Loss: 0.5683
# Validation Loss: 0.5812
# EarlyStopping counter: 1 out of 50
# Epoch 9
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7681304058549567
# Val Accuracy: 0.7385229540918163
# Training Loss: 0.5493
# Validation Loss: 0.5961
# EarlyStopping counter: 2 out of 50
# Epoch 10
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7634730538922155
# Val Accuracy: 0.7225548902195609
# Training Loss: 0.5504
# Validation Loss: 0.6160
# EarlyStopping counter: 3 out of 50
# Epoch 11
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7747837658017299
# Val Accuracy: 0.7744510978043913
# Training Loss: 0.5251
# Validation Loss: 0.5404
# Monitored metric has improved (0.554346 --> 0.540431).  Saving model ...
# Epoch 12
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7897538256819694
# Val Accuracy: 0.7624750499001997
# Training Loss: 0.5102
# Validation Loss: 0.5623
# EarlyStopping counter: 1 out of 50
# Epoch 13
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7864271457085829
# Val Accuracy: 0.7365269461077845
# Training Loss: 0.5078
# Validation Loss: 0.5916
# EarlyStopping counter: 2 out of 50
# Epoch 14
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.7954091816367266
# Val Accuracy: 0.7445109780439122
# Training Loss: 0.4892
# Validation Loss: 0.5881
# EarlyStopping counter: 3 out of 50
# Epoch 15
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8110445775116434
# Val Accuracy: 0.7485029940119761
# Training Loss: 0.4697
# Validation Loss: 0.5729
# EarlyStopping counter: 4 out of 50
# Epoch 16
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8013972055888223
# Val Accuracy: 0.7844311377245509
# Training Loss: 0.4776
# Validation Loss: 0.5253
# Monitored metric has improved (0.540431 --> 0.525268).  Saving model ...
# Epoch 17
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.811377245508982
# Val Accuracy: 0.7524950099800399
# Training Loss: 0.4500
# Validation Loss: 0.5839
# EarlyStopping counter: 1 out of 50
# Epoch 18
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8080505655355955
# Val Accuracy: 0.7524950099800399
# Training Loss: 0.4598
# Validation Loss: 0.5801
# EarlyStopping counter: 2 out of 50
# Epoch 19
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.824018629407851
# Val Accuracy: 0.7764471057884231
# Training Loss: 0.4271
# Validation Loss: 0.5520
# EarlyStopping counter: 3 out of 50
# Epoch 20
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.83166999334664
# Val Accuracy: 0.7624750499001997
# Training Loss: 0.4204
# Validation Loss: 0.5724
# EarlyStopping counter: 4 out of 50
# Epoch 21
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8290086493679308
# Val Accuracy: 0.7924151696606786
# Training Loss: 0.4087
# Validation Loss: 0.5383
# EarlyStopping counter: 5 out of 50
# Epoch 22
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8393213572854291
# Val Accuracy: 0.7664670658682635
# Training Loss: 0.4015
# Validation Loss: 0.5618
# EarlyStopping counter: 6 out of 50
# Epoch 23
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.843313373253493
# Val Accuracy: 0.7904191616766467
# Training Loss: 0.3939
# Validation Loss: 0.5189
# Monitored metric has improved (0.525268 --> 0.518889).  Saving model ...
# Epoch 24
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8386560212907518
# Val Accuracy: 0.7744510978043913
# Training Loss: 0.3953
# Validation Loss: 0.5542
# EarlyStopping counter: 1 out of 50
# Epoch 25
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8493013972055888
# Val Accuracy: 0.782435129740519
# Training Loss: 0.3740
# Validation Loss: 0.5425
# EarlyStopping counter: 2 out of 50
# Epoch 26
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8502994011976048
# Val Accuracy: 0.810379241516966
# Training Loss: 0.3682
# Validation Loss: 0.4970
# Monitored metric has improved (0.518889 --> 0.496963).  Saving model ...
# Epoch 27
# 3006/3006: [===============================>] - ETA 0.7s
# Train Accuracy: 0.8526280771789754
# Val Accuracy: 0.8003992015968064
# Training Loss: 0.3556
# Validation Loss: 0.5346
# EarlyStopping counter: 1 out of 50
# Epoch 28
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.866600133067199
# Val Accuracy: 0.7904191616766467
# Training Loss: 0.3370
# Validation Loss: 0.5475
# EarlyStopping counter: 2 out of 50
# Epoch 29
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.867598137059215
# Val Accuracy: 0.7964071856287425
# Training Loss: 0.3323
# Validation Loss: 0.5361
# EarlyStopping counter: 3 out of 50
# Epoch 30
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.874251497005988
# Val Accuracy: 0.8043912175648703
# Training Loss: 0.3192
# Validation Loss: 0.4808
# Monitored metric has improved (0.496963 --> 0.480763).  Saving model ...
# Epoch 31
# 3006/3006: [===============================>] - ETA 0.7s
# Train Accuracy: 0.8685961410512308
# Val Accuracy: 0.8143712574850299
# Training Loss: 0.3228
# Validation Loss: 0.5079
# EarlyStopping counter: 1 out of 50
# Epoch 32
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8805721889554224
# Val Accuracy: 0.782435129740519
# Training Loss: 0.3027
# Validation Loss: 0.5688
# EarlyStopping counter: 2 out of 50
# Epoch 33
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8759148369926814
# Val Accuracy: 0.8143712574850299
# Training Loss: 0.3080
# Validation Loss: 0.5130
# EarlyStopping counter: 3 out of 50
# Epoch 34
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8915502328675982
# Val Accuracy: 0.782435129740519
# Training Loss: 0.2897
# Validation Loss: 0.5614
# EarlyStopping counter: 4 out of 50
# Epoch 35
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8912175648702595
# Val Accuracy: 0.7904191616766467
# Training Loss: 0.2845
# Validation Loss: 0.5597
# EarlyStopping counter: 5 out of 50
# Epoch 36
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8925482368596142
# Val Accuracy: 0.7884231536926147
# Training Loss: 0.2697
# Validation Loss: 0.6144
# EarlyStopping counter: 6 out of 50
# Epoch 37
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.8962075848303394
# Val Accuracy: 0.7984031936127745
# Training Loss: 0.2614
# Validation Loss: 0.5389
# EarlyStopping counter: 7 out of 50
# Epoch 38
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.907185628742515
# Val Accuracy: 0.8223552894211577
# Training Loss: 0.2496
# Validation Loss: 0.5127
# EarlyStopping counter: 8 out of 50
# Epoch 39
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9041916167664671
# Val Accuracy: 0.7944111776447106
# Training Loss: 0.2552
# Validation Loss: 0.5788
# EarlyStopping counter: 9 out of 50
# Epoch 40
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9101796407185628
# Val Accuracy: 0.810379241516966
# Training Loss: 0.2321
# Validation Loss: 0.5245
# EarlyStopping counter: 10 out of 50
# Epoch 41
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9105123087159015
# Val Accuracy: 0.7904191616766467
# Training Loss: 0.2408
# Validation Loss: 0.5802
# EarlyStopping counter: 11 out of 50
# Epoch 42
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9161676646706587
# Val Accuracy: 0.782435129740519
# Training Loss: 0.2271
# Validation Loss: 0.6392
# EarlyStopping counter: 12 out of 50
# Epoch 43
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9151696606786427
# Val Accuracy: 0.8223552894211577
# Training Loss: 0.2214
# Validation Loss: 0.5280
# EarlyStopping counter: 13 out of 50
# Epoch 44
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9204923486360612
# Val Accuracy: 0.782435129740519
# Training Loss: 0.2066
# Validation Loss: 0.6239
# EarlyStopping counter: 14 out of 50
# Epoch 45
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9268130405854956
# Val Accuracy: 0.7924151696606786
# Training Loss: 0.1946
# Validation Loss: 0.6238
# EarlyStopping counter: 15 out of 50
# Epoch 46
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.928476380572189
# Val Accuracy: 0.7984031936127745
# Training Loss: 0.1924
# Validation Loss: 0.5990
# EarlyStopping counter: 16 out of 50
# Epoch 47
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9397870924817032
# Val Accuracy: 0.7924151696606786
# Training Loss: 0.1772
# Validation Loss: 0.6092
# EarlyStopping counter: 17 out of 50
# Epoch 48
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.929474384564205
# Val Accuracy: 0.7924151696606786
# Training Loss: 0.1861
# Validation Loss: 0.5921
# EarlyStopping counter: 18 out of 50
# Epoch 49
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9344644045242848
# Val Accuracy: 0.7964071856287425
# Training Loss: 0.1713
# Validation Loss: 0.6082
# EarlyStopping counter: 19 out of 50
# Epoch 50
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9407850964737192
# Val Accuracy: 0.7844311377245509
# Training Loss: 0.1714
# Validation Loss: 0.6060
# EarlyStopping counter: 20 out of 50
# Epoch 51
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9421157684630739
# Val Accuracy: 0.7884231536926147
# Training Loss: 0.1551
# Validation Loss: 0.6407
# EarlyStopping counter: 21 out of 50
# Epoch 52
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9407850964737192
# Val Accuracy: 0.7944111776447106
# Training Loss: 0.1567
# Validation Loss: 0.6443
# EarlyStopping counter: 22 out of 50
# Epoch 53
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.947771124417831
# Val Accuracy: 0.8223552894211577
# Training Loss: 0.1437
# Validation Loss: 0.5853
# EarlyStopping counter: 23 out of 50
# Epoch 54
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9431137724550899
# Val Accuracy: 0.7904191616766467
# Training Loss: 0.1481
# Validation Loss: 0.6498
# EarlyStopping counter: 24 out of 50
# Epoch 55
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9557551563539588
# Val Accuracy: 0.7964071856287425
# Training Loss: 0.1298
# Validation Loss: 0.6612
# EarlyStopping counter: 25 out of 50
# Epoch 56
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.956420492348636
# Val Accuracy: 0.7944111776447106
# Training Loss: 0.1245
# Validation Loss: 0.6513
# EarlyStopping counter: 26 out of 50
# Epoch 57
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9557551563539588
# Val Accuracy: 0.7924151696606786
# Training Loss: 0.1233
# Validation Loss: 0.6869
# EarlyStopping counter: 27 out of 50
# Epoch 58
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9620758483033932
# Val Accuracy: 0.812375249500998
# Training Loss: 0.1145
# Validation Loss: 0.5847
# EarlyStopping counter: 28 out of 50
# Epoch 59
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9577511643379907
# Val Accuracy: 0.8063872255489022
# Training Loss: 0.1221
# Validation Loss: 0.6926
# EarlyStopping counter: 29 out of 50
# Epoch 60
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9677312042581504
# Val Accuracy: 0.812375249500998
# Training Loss: 0.1061
# Validation Loss: 0.5969
# EarlyStopping counter: 30 out of 50
# Epoch 61
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9677312042581504
# Val Accuracy: 0.7844311377245509
# Training Loss: 0.1013
# Validation Loss: 0.7035
# EarlyStopping counter: 31 out of 50
# Epoch 62
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9617431803060545
# Val Accuracy: 0.8043912175648703
# Training Loss: 0.1052
# Validation Loss: 0.6697
# EarlyStopping counter: 32 out of 50
# Epoch 63
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.969061876247505
# Val Accuracy: 0.7744510978043913
# Training Loss: 0.1026
# Validation Loss: 0.8049
# EarlyStopping counter: 33 out of 50
# Epoch 64
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.969061876247505
# Val Accuracy: 0.7964071856287425
# Training Loss: 0.0911
# Validation Loss: 0.6966
# EarlyStopping counter: 34 out of 50
# Epoch 65
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9710578842315369
# Val Accuracy: 0.7844311377245509
# Training Loss: 0.0864
# Validation Loss: 0.7152
# EarlyStopping counter: 35 out of 50
# Epoch 66
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9780439121756487
# Val Accuracy: 0.8003992015968064
# Training Loss: 0.0772
# Validation Loss: 0.6499
# EarlyStopping counter: 36 out of 50
# Epoch 67
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9720558882235529
# Val Accuracy: 0.782435129740519
# Training Loss: 0.0858
# Validation Loss: 0.7708
# EarlyStopping counter: 37 out of 50
# Epoch 68
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9683965402528277
# Val Accuracy: 0.8003992015968064
# Training Loss: 0.0951
# Validation Loss: 0.6776
# EarlyStopping counter: 38 out of 50
# Epoch 69
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9757152361942781
# Val Accuracy: 0.7964071856287425
# Training Loss: 0.0751
# Validation Loss: 0.6941
# EarlyStopping counter: 39 out of 50
# Epoch 70
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9740518962075848
# Val Accuracy: 0.7864271457085829
# Training Loss: 0.0785
# Validation Loss: 0.8140
# EarlyStopping counter: 40 out of 50
# Epoch 71
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9757152361942781
# Val Accuracy: 0.7864271457085829
# Training Loss: 0.0720
# Validation Loss: 0.7743
# EarlyStopping counter: 41 out of 50
# Epoch 72
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9767132401862941
# Val Accuracy: 0.7884231536926147
# Training Loss: 0.0673
# Validation Loss: 0.7427
# EarlyStopping counter: 42 out of 50
# Epoch 73
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9753825681969395
# Val Accuracy: 0.8043912175648703
# Training Loss: 0.0747
# Validation Loss: 0.7057
# EarlyStopping counter: 43 out of 50
# Epoch 74
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.978709248170326
# Val Accuracy: 0.7964071856287425
# Training Loss: 0.0634
# Validation Loss: 0.7538
# EarlyStopping counter: 44 out of 50
# Epoch 75
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9840319361277445
# Val Accuracy: 0.8003992015968064
# Training Loss: 0.0516
# Validation Loss: 0.7274
# EarlyStopping counter: 45 out of 50
# Epoch 76
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.97771124417831
# Val Accuracy: 0.8183632734530938
# Training Loss: 0.0601
# Validation Loss: 0.7056
# EarlyStopping counter: 46 out of 50
# Epoch 77
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9833666001330672
# Val Accuracy: 0.8243512974051896
# Training Loss: 0.0555
# Validation Loss: 0.7016
# EarlyStopping counter: 47 out of 50
# Epoch 78
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.979707252162342
# Val Accuracy: 0.812375249500998
# Training Loss: 0.0619
# Validation Loss: 0.7554
# EarlyStopping counter: 48 out of 50
# Epoch 79
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9860279441117764
# Val Accuracy: 0.8003992015968064
# Training Loss: 0.0481
# Validation Loss: 0.8284
# EarlyStopping counter: 49 out of 50
# Epoch 80
# 3006/3006: [===============================>] - ETA 0.6s
# Train Accuracy: 0.9830339321357285
# Val Accuracy: 0.812375249500998
# Training Loss: 0.0557
# Validation Loss: 0.7411
# EarlyStopping counter: 50 out of 50
# Early stopping

# %%
# load the last checkpoint with the best model

model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/Section6_CP2_project/ham10000_dataset/skin_models_segmented/skinmodel50.pt')) 
# model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/new_data_v3/skin_models_not_segmented/skinmodel50.pt', map_location=torch.device('cpu')))  #cpu
# Out:
# <All keys matched successfully>

# %%
class_names = train_dataset.classes
print('클래스:', class_names)
# Out:
# 클래스: ['MEL', 'NV', 'Other_SC']

# %%
import time
import matplotlib.pyplot as plt

def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0))
    # 이미지 정규화 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.figure(figsize=(10, 10))
    plt.imshow(input)
    plt.title(title)
    plt.show()

# %%
y_pred = []
y_true = []

model.eval()
start_time = time.time()
with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])
        y_pred += preds.tolist()
        y_true += labels.data.tolist()


    epoch_loss = running_loss / len(test_dataset)
    epoch_acc = running_corrects / len(test_dataset) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# [예측 결과: Other_SC] (실제 정답: Other_SC)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0, flags=flags)
# [예측 결과: NV] (실제 정답: NV)
# [예측 결과: Other_SC] (실제 정답: Other_SC)
# [예측 결과: Other_SC] (실제 정답: MEL)
# [예측 결과: NV] (실제 정답: NV)
# [예측 결과: NV] (실제 정답: NV)
# [예측 결과: NV] (실제 정답: NV)
# [Test Phase] Loss: 0.4447 Acc: 83.0424% Time: 72.9383s

# %% [markdown]
# #5.결과출력

# %%
# num_classes = 3

# predlist = torch.zeros(0,dtype=torch.long, device='cpu')
# lbllist = torch.zeros(0,dtype=torch.long, device='cpu')
# predlistauc = torch.zeros(0,dtype=torch.long, device='cpu')
# with torch.no_grad():
#     for i, (inputs, classes) in enumerate(test_loader):
#         model.eval()
#         inputs = inputs.to(device)
#         classes = classes.to(device)
#         outputs = model(inputs)
#         _, preds = torch.max(outputs, 1)

#         # Append batch prediction results
#         predlist=torch.cat([predlist,preds.view(-1).cpu()])
#         lbllist=torch.cat([lbllist,classes.view(-1).cpu()])
#         predlistauc = torch.cat([predlistauc,nn.functional.softmax(outputs, dim=1).cpu()])
# predlist = predlist.numpy()
# lbllist = lbllist.numpy()
# predlistauc = predlistauc.numpy()

# # Confusion matrix, classification report and AUC
# conf_mat=confusion_matrix(lbllist, predlist)
# target_names = class_names
# ConfusionMatrixDisplay(conf_mat, display_labels=target_names).plot(values_format="d")
# print(classification_report(lbllist, predlist, target_names=target_names))
# lbllist_one_hot = nn.functional.one_hot(torch.tensor([lbllist]), num_classes=num_classes)
# every_auc = roc_auc_score(lbllist_one_hot.view([predlistauc.shape[0], predlistauc.shape[1]]), 
#                                           predlistauc, multi_class='ovr', average=None)
# for i, every in enumerate(target_names):
#     print(f'AUC of class {every} = {every_auc[i]}')

# %%
# confusion matrix
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)        
length=len(class_names)
if length < 8:
  fig_width = 8
  fig_height = 8
else:
  fig_width= int(length * .5)
  fig_height= int(length * .5)

plt.figure(figsize=(fig_width, fig_height))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
plt.xticks(np.arange(length)+.5, class_names, rotation= 90)
plt.yticks(np.arange(length)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
clr = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#          MEL       0.63      0.71      0.67        51
#           NV       0.94      0.85      0.89       273
#     Other_SC       0.67      0.86      0.75        77
#
#     accuracy                           0.83       401
#    macro avg       0.75      0.80      0.77       401
# weighted avg       0.85      0.83      0.84       401
